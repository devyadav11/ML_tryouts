# %% [markdown]
# <a href="https://colab.research.google.com/github/devyadav11/project-1/blob/main/Beam_Splitter_Attack_DPS_QKD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math



def poisson_probability(n, mu):
    """Calculate the probability P(n) for a Poisson distribution in a coherent state."""

    return (math.exp(-mu) * mu**(n)) / math.factorial(n)

# Example: Compute P(1) for a given alpha (mean photon number)
mu = 0.1  # Example value of alpha
n = 2
probability = poisson_probability(n, mu)
print(f"P({n}) = {probability:.4f}")
# Out:
# P(2) = 0.0045

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

def poisson_probability(n, mu):
    """Calculate the probability P(n) for a Poisson distribution."""
    return (math.exp(-mu) * mu**n) / math.factorial(n)

# Define parameters
mu = 0.1  # Mean photon number
n_values = np.arange(0, 10)  # Range of photon numbers (0 to 9)
probabilities = [poisson_probability(n, mu) for n in n_values]

# Print P(1) result
print(f"P(1) = {poisson_probability(1, mu):.4f}")

# Plot the Poisson distribution
plt.figure(figsize=(8, 5))
plt.bar(n_values, probabilities, color='b', alpha=0.7, label=f"Poisson Distribution (μ={mu})")
plt.xlabel("Photon Number (n)")
plt.ylabel("Probability P(n)")
plt.title("Poisson Distribution for a Coherent State")
plt.xticks(n_values)
plt.legend()
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.show()
# Out:
# P(1) = 0.0905

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

def poisson_probability(n, mu):
    """Calculate the probability P(n) for a Poisson distribution in a coherent state."""
    return (math.exp(-mu) * mu**n) / math.factorial(n)


n = 2

# Define mean photon number (mu) range
mu_values = np.linspace(0, 10, 100)  # Mean photon number from 0 to 5
probabilities = [poisson_probability(n, mu) for mu in mu_values]  # Compute P(2) for each mu

# Plot the probability distribution
plt.figure(figsize=(8, 5))
plt.plot(mu_values, probabilities, label=r'$P(2) = \frac{e^{-\mu} \mu^2}{2!}$', color='b', linewidth=2)
plt.xlabel(r"Mean Photon Number ($\mu$)")
plt.ylabel(r"Probability $P(2)$")
plt.title("Poisson Probability of 2 Photons vs Mean Photon Number")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()

# %%
# prompt: in the above curve plot the curves for mean photon number 1, 2, 3, 4, 5 in one curve

import math
import numpy as np
import matplotlib.pyplot as plt

def poisson_probability(n, mu):
    """Calculate the probability P(n) for a Poisson distribution."""
    return (math.exp(-mu) * mu**n) / math.factorial(n)

# Define mean photon numbers
mu_values = [1, 2, 3, 4, 5]

# Define photon number range
n_values = np.arange(0, 10)

# Create the plot
plt.figure(figsize=(10, 6))

# Plot for each mean photon number
for mu in mu_values:
    probabilities = [poisson_probability(n, mu) for n in n_values]
    plt.plot(n_values, probabilities, label=f"μ = {mu}")

# Customize the plot
plt.xlabel("Photon Number (n)")
plt.ylabel("Probability P(n)")
plt.title("Poisson Distribution for Different Mean Photon Numbers")
plt.xticks(n_values)
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
# prompt: proboblity v\s mean photon number for n = 1,2,3,4,5

import math
import numpy as np
import matplotlib.pyplot as plt

def poisson_probability(n, mu):
    """Calculate the probability P(n) for a Poisson distribution."""
    return (math.exp(-mu) * mu**n) / math.factorial(n)

# Define mean photon numbers
mu_values = np.linspace(0, 10, 100)  # Smooth range for the x-axis

# Define photon numbers
n_values = [1, 2, 3, 4, 5]

# Create the plot
plt.figure(figsize=(10, 6))

# Plot for each photon number
for n in n_values:
    probabilities = [poisson_probability(n, mu) for mu in mu_values]
    plt.plot(mu_values, probabilities, label=f"n = {n}")

# Customize the plot
plt.xlabel("Mean Photon Number (μ)")
plt.ylabel("Probability P(n)")
plt.title("Poisson Probability vs. Mean Photon Number for Different n")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
# prompt: mark on each curve at mean photon number 1, 2, 3, 4, and 5 and also give the corresponding probability values of each curve  n = 1,2,3,4,5  (give us the values)

import math
import numpy as np
import matplotlib.pyplot as plt

def poisson_probability(n, mu):
    """Calculate the probability P(n) for a Poisson distribution."""
    return (math.exp(-mu) * mu**n) / math.factorial(n)

# Define mean photon numbers
mu_values = np.linspace(0, 10, 100)  # Smooth range for the x-axis

# Define photon numbers
n_values = [1, 2, 3, 4, 5]

# Create the plot
plt.figure(figsize=(10, 6))

# Plot for each photon number and mark points at mu = 1, 2, 3, 4, 5
for n in n_values:
    probabilities = [poisson_probability(n, mu) for mu in mu_values]
    plt.plot(mu_values, probabilities, label=f"n = {n}")
    for mu_mark in [1, 2, 3, 4, 5]:
        prob = poisson_probability(n, mu_mark)
        plt.plot(mu_mark, prob, marker='o', markersize=5, color='red')  # Mark points in red
        print(f"For n = {n}, mu = {mu_mark}, P(n) = {prob:.4f}")

# Customize the plot
plt.xlabel("Mean Photon Number (μ)")
plt.ylabel("Probability P(n)")
plt.title("Poisson Probability vs. Mean Photon Number for Different n")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()
# Out:
# For n = 1, mu = 1, P(n) = 0.3679
# For n = 1, mu = 2, P(n) = 0.2707
# For n = 1, mu = 3, P(n) = 0.1494
# For n = 1, mu = 4, P(n) = 0.0733
# For n = 1, mu = 5, P(n) = 0.0337
# For n = 2, mu = 1, P(n) = 0.1839
# For n = 2, mu = 2, P(n) = 0.2707
# For n = 2, mu = 3, P(n) = 0.2240
# For n = 2, mu = 4, P(n) = 0.1465
# For n = 2, mu = 5, P(n) = 0.0842
# For n = 3, mu = 1, P(n) = 0.0613
# For n = 3, mu = 2, P(n) = 0.1804
# For n = 3, mu = 3, P(n) = 0.2240
# For n = 3, mu = 4, P(n) = 0.1954
# For n = 3, mu = 5, P(n) = 0.1404
# For n = 4, mu = 1, P(n) = 0.0153
# For n = 4, mu = 2, P(n) = 0.0902
# For n = 4, mu = 3, P(n) = 0.1680
# For n = 4, mu = 4, P(n) = 0.1954
# For n = 4, mu = 5, P(n) = 0.1755
# For n = 5, mu = 1, P(n) = 0.0031
# For n = 5, mu = 2, P(n) = 0.0361
# For n = 5, mu = 3, P(n) = 0.1008
# For n = 5, mu = 4, P(n) = 0.1563
# For n = 5, mu = 5, P(n) = 0.1755

# %%
import math

# Constants
h = 6.626e-34  # Planck's constant (Joule-seconds)
c = 3.0e8      # Speed of light (m/s)

def calculate_pulse_power(mu, wavelength, time_period):
    """
    Calculate pulse power (P) in watts given mean photon number (mu),
    wavelength (lambda), and time period (T).
    """
    return (mu * h * c) / (wavelength * time_period)

def convert_to_mW(power_watt):
    """Convert power from Watts to milliwatts (mW)."""
    return power_watt * 1e3  # 1W = 1000mW

def convert_to_dBm(power_mW):
    """Convert power from mW to dBm."""
    return 10 * math.log10(power_mW) if power_mW > 0 else float('-inf')  # Avoid log(0) error

# Example Parameters
mu = 5  # Mean photon number
wavelength = 1550e-9  # Wavelength in meters (e.g., 1550 nm for telecom fiber)
time_period = 3e-9  # Time period in seconds (1 ns pulse duration)

# Compute power in Watts
power_watt = calculate_pulse_power(mu, wavelength, time_period)

# Convert to mW and dBm
power_mW = convert_to_mW(power_watt)
power_dBm = convert_to_dBm(power_mW)

# Display results
print(f"Pulse Power: {power_watt:.6e} W")
print(f"Pulse Power: {power_mW:.10f} mW")
print(f"Pulse Power: {power_dBm:.2f} dBm")
# Out:
# Pulse Power: 2.137419e-10 W
# Pulse Power: 0.0000002137 mW
# Pulse Power: -66.70 dBm
